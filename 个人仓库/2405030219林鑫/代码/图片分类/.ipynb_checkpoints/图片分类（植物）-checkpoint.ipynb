# %%
import os
import time
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS

# %%
#配置 
data_root = "./data1"  
batch_size = 64
num_epochs = 30
lr = 0.001
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# 数据预处理

# %%
#训练增强
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),#裁剪到244*244格式
    transforms.RandomHorizontalFlip(),#随机水平翻转
    transforms.ToTensor(),#转为张量
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])#采用ImageNet通用均值和标准差
])
#验证只用基本变换
val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
#加载数据（ImageFolder：根据文件夹自动生成分类标签）
train_dataset = datasets.ImageFolder(root=os.path.join(data_root, "train"), transform=train_transform)
val_dataset   = datasets.ImageFolder(root=os.path.join(data_root, "val"), transform=val_transform)
#打包分批
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
val_loader   = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

num_classes = len(train_dataset.classes)
print(f"类别数：{num_classes}")
print(f"类别：{train_dataset.classes}")
# Out:
# 类别数：30
# 类别：['aloevera', 'banana', 'bilimbi', 'cantaloupe', 'cassava', 'coconut', 'corn', 'cucumber', 'curcuma', 'eggplant', 'galangal', 'ginger', 'guava', 'kale', 'longbeans', 'mango', 'melon', 'orange', 'paddy', 'papaya', 'peperchili', 'pineapple', 'pomelo', 'shallot', 'soybeans', 'spinach', 'sweetpotatoes', 'tobacco', 'waterapple', 'watermelon']

# %%
#可配置的 ResNet
class BasicBlock(nn.Module):
    expansion = 1 #ResNet固定参数
    def __init__(self, in_planes, planes, stride=1, use_bn=True, use_res=True):
        super().__init__()
        #全局开关
        self.use_bn = use_bn  #是否启用批量归一化
        self.use_res = use_res #是否启用残差链接

        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=not use_bn)
        self.bn1 = nn.BatchNorm2d(planes) if use_bn else nn.Identity()
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=not use_bn)
        self.bn2 = nn.BatchNorm2d(planes) if use_bn else nn.Identity()
        #输入x维度与输出不一致时，用1*1卷积对齐尺寸
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes) if use_bn else nn.Identity()
            )
    #向前传播forward
    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        if self.use_res:
            out += self.shortcut(x)
        out = torch.relu(out)
        return out

# %% [markdown]
# ResNet类

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=1000, use_bn=True, use_res=True):
        super().__init__()
        self.in_planes = 64
        self.use_bn = use_bn
        self.use_res = use_res
        #网络架构
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=not use_bn)
        self.bn1 = nn.BatchNorm2d(64) if use_bn else nn.Identity()
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)
        #残差构造函数
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride, self.use_bn, self.use_res))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = torch.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = torch.flatten(out, 1)
        out = self.fc(out)
        return out
#快捷构建函数
def resnet18(num_classes=num_classes, use_bn=True, use_res=True):
    return ResNet(BasicBlock, [2,2,2,2], num_classes, use_bn, use_res)

# %% [markdown]
# 训练和验证函数

# %%
#单论训练函数
def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * inputs.size(0)
        _, pred = outputs.max(1)
        correct += pred.eq(labels).sum().item()
        total += labels.size(0)
    avg_loss = total_loss / total
    acc = 100. * correct / total
    return avg_loss, acc
#评估函数
def validate(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            _, pred = outputs.max(1)
            correct += pred.eq(labels).sum().item()
            total += labels.size(0)
    avg_loss = total_loss / total
    acc = 100. * correct / total
    return avg_loss, acc
#训练主函数
def train_model(model, name, epochs=num_epochs):
    print(f"\n===== 开始训练：{name} =====")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    best_acc = 0.0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    for epoch in range(1, epochs+1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc = validate(model, val_loader, criterion, device)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)
        print(f"Epoch {epoch:2d} | Train Loss: {train_loss:.4f} Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f} Acc: {val_acc:.2f}%")
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), f"{name}_best.pth")
    print(f"{name} 最佳验证准确率: {best_acc:.2f}%")
    return history, best_acc

# %% [markdown]
# 开始训练

# %%
results = {}
# 标准 ResNet
model_std = resnet18(use_bn=True, use_res=True)
hist_std, acc_std = train_model(model_std, "ResNet_standard")

#去掉 BN
model_no_bn = resnet18(use_bn=False, use_res=True)
hist_no_bn, acc_no_bn = train_model(model_no_bn, "ResNet_no_BN")

#去掉残差
model_no_res = resnet18(use_bn=True, use_res=False)
hist_no_res, acc_no_res = train_model(model_no_res, "ResNet_no_residual")

# %% [markdown]
# 绘制损失和准确率曲线

# %%
def plot_history(histories, title):
    plt.figure(figsize=(12,4))
    for name, hist in histories.items():
        plt.subplot(1,2,1)
        plt.plot(hist['val_acc'], label=name)
        plt.title('Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Acc (%)')
        plt.legend()
        plt.subplot(1,2,2)
        plt.plot(hist['val_loss'], label=name)
        plt.title('Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
    plt.suptitle(title)
    plt.tight_layout()
    plt.savefig(f"{title}.png")
    plt.show()

all_hist = {
    "Standard": hist_std,
    "No BN": hist_no_bn,
    "No Residual": hist_no_res
}
plot_history(all_hist, "Comparison_ResNet_Experiments")

# %% [markdown]
# 抽样预测

# %%
def show_predictions(model, val_loader, device, num_images=6):
    model.eval()
    images, labels, preds = [], [], []
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            images.extend(inputs.cpu())
            labels.extend(targets)
            preds.extend(predicted.cpu())
            if len(images) >= num_images:
                break
    # 反归一化
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)
    plt.figure(figsize=(12, 8))
    for i in range(num_images):
        plt.subplot(2, 3, i+1)
        img = images[i] * std + mean  # 反归一化
        img = img.clamp(0, 1).permute(1,2,0)
        plt.imshow(img)
        true_label = val_dataset.classes[labels[i]]
        pred_label = val_dataset.classes[preds[i]]
        color = 'green' if labels[i] == preds[i] else 'red'
        plt.title(f'True: {true_label}\nPred: {pred_label}', color=color, fontsize=10)
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('sample_predictions.png')
    plt.show()

# 调用（以标准模型为例）
show_predictions(model_std, val_loader, device, num_images=6)
# Out:
# ===== 开始训练：ResNet_standard =====
# Epoch  1 | Train Loss: 2.7190 Acc: 21.02% | Val Loss: 2.4115 Acc: 29.93%
# Epoch  2 | Train Loss: 2.5003 Acc: 27.91% | Val Loss: 2.2325 Acc: 34.13%
# Epoch  3 | Train Loss: 2.3900 Acc: 30.76% | Val Loss: 2.0865 Acc: 37.17%
# Epoch  4 | Train Loss: 2.3119 Acc: 33.15% | Val Loss: 2.0163 Acc: 40.87%
# Epoch  5 | Train Loss: 2.2191 Acc: 35.80% | Val Loss: 2.0741 Acc: 40.23%
# Epoch  6 | Train Loss: 2.1450 Acc: 38.09% | Val Loss: 1.9077 Acc: 44.27%
# Epoch  7 | Train Loss: 2.0692 Acc: 40.03% | Val Loss: 1.8434 Acc: 46.97%
# Epoch  8 | Train Loss: 2.0044 Acc: 42.09% | Val Loss: 1.7130 Acc: 52.53%
# Epoch  9 | Train Loss: 1.9333 Acc: 44.08% | Val Loss: 1.7007 Acc: 51.87%
# Epoch 10 | Train Loss: 1.8743 Acc: 45.38% | Val Loss: 1.5719 Acc: 55.17%
# Epoch 11 | Train Loss: 1.8189 Acc: 47.18% | Val Loss: 1.4879 Acc: 55.77%
# Epoch 12 | Train Loss: 1.7328 Acc: 49.57% | Val Loss: 1.4695 Acc: 54.93%
# Epoch 13 | Train Loss: 1.6852 Acc: 50.88% | Val Loss: 1.4513 Acc: 57.87%
# Epoch 14 | Train Loss: 1.6367 Acc: 52.29% | Val Loss: 1.3420 Acc: 60.53%
# Epoch 15 | Train Loss: 1.5772 Acc: 53.88% | Val Loss: 1.3013 Acc: 62.23%
# Epoch 16 | Train Loss: 1.5263 Acc: 55.08% | Val Loss: 1.2749 Acc: 62.30%
# Epoch 17 | Train Loss: 1.4649 Acc: 57.25% | Val Loss: 1.5468 Acc: 56.70%
# Epoch 18 | Train Loss: 1.4407 Acc: 57.79% | Val Loss: 1.2002 Acc: 64.50%
# Epoch 19 | Train Loss: 1.3821 Acc: 59.61% | Val Loss: 1.1226 Acc: 65.83%
# Epoch 20 | Train Loss: 1.3736 Acc: 59.70% | Val Loss: 1.1559 Acc: 65.50%
# Epoch 21 | Train Loss: 1.3056 Acc: 61.46% | Val Loss: 1.1882 Acc: 64.30%
# Epoch 22 | Train Loss: 1.2578 Acc: 62.53% | Val Loss: 1.0407 Acc: 69.37%
# Epoch 23 | Train Loss: 1.2194 Acc: 63.64% | Val Loss: 1.0643 Acc: 67.87%
# Epoch 24 | Train Loss: 1.1864 Acc: 64.16% | Val Loss: 0.9374 Acc: 71.33%
# Epoch 25 | Train Loss: 1.1593 Acc: 64.68% | Val Loss: 1.0244 Acc: 70.87%
# Epoch 26 | Train Loss: 1.1243 Acc: 66.32% | Val Loss: 0.9037 Acc: 72.43%
# Epoch 27 | Train Loss: 1.0953 Acc: 67.00% | Val Loss: 0.8611 Acc: 73.17%
# Epoch 28 | Train Loss: 1.0797 Acc: 67.48% | Val Loss: 0.8713 Acc: 74.63%
# Epoch 29 | Train Loss: 1.0469 Acc: 68.28% | Val Loss: 0.7993 Acc: 75.10%
# Epoch 30 | Train Loss: 1.0101 Acc: 69.22% | Val Loss: 1.1165 Acc: 70.03%
# ResNet_standard 最佳验证准确率: 75.10%
#
# ===== 开始训练：ResNet_no_BN =====
# Epoch  1 | Train Loss: 3.2532 Acc: 7.35% | Val Loss: 3.0610 Acc: 9.47%
# Epoch  2 | Train Loss: 2.8352 Acc: 15.83% | Val Loss: 2.6107 Acc: 25.13%
# Epoch  3 | Train Loss: 2.6397 Acc: 22.06% | Val Loss: 2.4176 Acc: 28.37%
# Epoch  4 | Train Loss: 2.4868 Acc: 26.91% | Val Loss: 2.1824 Acc: 34.70%
# Epoch  5 | Train Loss: 2.3263 Acc: 31.70% | Val Loss: 2.0389 Acc: 40.50%
# Epoch  6 | Train Loss: 2.1874 Acc: 35.75% | Val Loss: 1.8449 Acc: 45.77%
# Epoch  7 | Train Loss: 2.0425 Acc: 40.13% | Val Loss: 1.6828 Acc: 50.10%
# Epoch  8 | Train Loss: 1.9390 Acc: 43.09% | Val Loss: 1.5820 Acc: 53.50%
# Epoch  9 | Train Loss: 1.8349 Acc: 46.16% | Val Loss: 1.5218 Acc: 55.47%
# Epoch 10 | Train Loss: 1.7431 Acc: 48.70% | Val Loss: 1.5498 Acc: 55.77%
# Epoch 11 | Train Loss: 1.6703 Acc: 51.11% | Val Loss: 1.3126 Acc: 61.23%
# Epoch 12 | Train Loss: 1.5760 Acc: 53.40% | Val Loss: 1.3204 Acc: 60.97%
# Epoch 13 | Train Loss: 1.5275 Acc: 54.84% | Val Loss: 1.2520 Acc: 62.60%
# Epoch 14 | Train Loss: 1.4649 Acc: 56.56% | Val Loss: 1.1655 Acc: 64.77%
# Epoch 15 | Train Loss: 1.3995 Acc: 58.43% | Val Loss: 1.2458 Acc: 64.20%
# Epoch 16 | Train Loss: 1.3613 Acc: 59.45% | Val Loss: 1.0940 Acc: 67.60%
# Epoch 17 | Train Loss: 1.3281 Acc: 60.35% | Val Loss: 1.1016 Acc: 67.17%
# Epoch 18 | Train Loss: 1.2772 Acc: 61.88% | Val Loss: 0.9988 Acc: 69.20%
# Epoch 19 | Train Loss: 1.2290 Acc: 62.96% | Val Loss: 0.9613 Acc: 71.83%
# Epoch 20 | Train Loss: 1.1783 Acc: 64.33% | Val Loss: 0.9527 Acc: 71.43%
# Epoch 21 | Train Loss: 1.1643 Acc: 64.45% | Val Loss: 0.9160 Acc: 72.27%
# Epoch 22 | Train Loss: 1.1147 Acc: 65.98% | Val Loss: 0.9384 Acc: 72.20%
# Epoch 23 | Train Loss: 1.1011 Acc: 66.52% | Val Loss: 0.8546 Acc: 74.37%
# Epoch 24 | Train Loss: 1.0752 Acc: 66.94% | Val Loss: 0.8701 Acc: 73.80%
# Epoch 25 | Train Loss: 1.0308 Acc: 68.61% | Val Loss: 0.8459 Acc: 74.97%
# Epoch 26 | Train Loss: 1.0066 Acc: 69.10% | Val Loss: 0.8905 Acc: 74.00%
# Epoch 27 | Train Loss: 0.9661 Acc: 70.81% | Val Loss: 0.7753 Acc: 75.77%
# Epoch 28 | Train Loss: 0.9520 Acc: 70.89% | Val Loss: 0.8164 Acc: 74.70%
# Epoch 29 | Train Loss: 0.9177 Acc: 71.60% | Val Loss: 0.8286 Acc: 74.87%
# Epoch 30 | Train Loss: 0.9179 Acc: 71.57% | Val Loss: 0.7989 Acc: 75.60%
# ResNet_no_BN 最佳验证准确率: 75.77%
#
# ===== 开始训练：ResNet_no_residual =====
# Epoch  1 | Train Loss: 2.8952 Acc: 14.49% | Val Loss: 3.0121 Acc: 14.50%
# Epoch  2 | Train Loss: 2.7216 Acc: 18.89% | Val Loss: 2.6006 Acc: 23.50%
# Epoch  3 | Train Loss: 2.6370 Acc: 21.52% | Val Loss: 2.4795 Acc: 24.50%
# Epoch  4 | Train Loss: 2.5900 Acc: 23.54% | Val Loss: 2.4938 Acc: 25.03%
# Epoch  5 | Train Loss: 2.5262 Acc: 25.18% | Val Loss: 2.5080 Acc: 26.27%
# Epoch  6 | Train Loss: 2.4679 Acc: 26.77% | Val Loss: 2.6548 Acc: 26.37%
# Epoch  7 | Train Loss: 2.4090 Acc: 29.28% | Val Loss: 2.2200 Acc: 34.67%
# Epoch  8 | Train Loss: 2.3290 Acc: 31.35% | Val Loss: 2.0608 Acc: 38.73%
# Epoch  9 | Train Loss: 2.2767 Acc: 33.15% | Val Loss: 2.0877 Acc: 39.33%
# Epoch 10 | Train Loss: 2.2089 Acc: 34.49% | Val Loss: 2.1331 Acc: 38.90%
# Epoch 11 | Train Loss: 2.1946 Acc: 35.31% | Val Loss: 1.9892 Acc: 42.00%
# Epoch 12 | Train Loss: 2.1371 Acc: 37.09% | Val Loss: 1.8964 Acc: 44.97%
# Epoch 13 | Train Loss: 2.0835 Acc: 38.98% | Val Loss: 1.8353 Acc: 46.43%
# Epoch 14 | Train Loss: 2.0520 Acc: 40.34% | Val Loss: 1.8162 Acc: 47.10%
# Epoch 15 | Train Loss: 2.0068 Acc: 41.27% | Val Loss: 1.8608 Acc: 45.20%
# Epoch 17 | Train Loss: 1.9270 Acc: 43.35% | Val Loss: 1.6235 Acc: 52.07%
# Epoch 18 | Train Loss: 1.8689 Acc: 44.77% | Val Loss: 1.4961 Acc: 55.03%
# Epoch 19 | Train Loss: 1.8384 Acc: 45.79% | Val Loss: 1.5027 Acc: 54.50%
# Epoch 20 | Train Loss: 1.8023 Acc: 46.86% | Val Loss: 1.5509 Acc: 55.00%
# Epoch 21 | Train Loss: 1.7699 Acc: 47.89% | Val Loss: 1.4015 Acc: 58.47%
# Epoch 22 | Train Loss: 1.7411 Acc: 48.72% | Val Loss: 1.3765 Acc: 59.20%
# Epoch 23 | Train Loss: 1.7053 Acc: 49.75% | Val Loss: 1.3884 Acc: 58.30%
# Epoch 24 | Train Loss: 1.6641 Acc: 50.97% | Val Loss: 1.4083 Acc: 57.73%
# Epoch 25 | Train Loss: 1.6379 Acc: 51.83% | Val Loss: 1.2900 Acc: 62.00%
# Epoch 26 | Train Loss: 1.5954 Acc: 52.86% | Val Loss: 1.2696 Acc: 61.40%
# Epoch 27 | Train Loss: 1.5568 Acc: 53.75% | Val Loss: 1.2742 Acc: 60.60%
# Epoch 28 | Train Loss: 1.5350 Acc: 54.48% | Val Loss: 1.2553 Acc: 63.80%
# Epoch 29 | Train Loss: 1.5039 Acc: 55.55% | Val Loss: 1.2486 Acc: 61.33%
# Epoch 30 | Train Loss: 1.4675 Acc: 56.33% | Val Loss: 1.2002 Acc: 63.77%
# ResNet_no_residual 最佳验证准确率: 63.80%
#
# ==================================================
# 最终结果对比
# 标准 ResNet       : 最佳验证准确率 = 75.10%
# 去掉 BatchNorm    : 最佳验证准确率 = 75.77%
# 去掉残差连接      : 最佳验证准确率 = 63.80%
# ==================================================
